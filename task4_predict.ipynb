# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasriponali/masai/blob/main/task4_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pandas

# !pip3 install scikit-learn

# %%
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

from sklearn.metrics import classification_report

# %%
df = pd.read_csv("/content/churnguard_data (4).csv")
df
# Out:
#      customerID      gender  SeniorCitizen  tenure PhoneService  \
# 0     CUST-0032        Male              0    21.0          YES
# 1     CUST-0110        Male              0    55.0          YES
# 2     CUST-0137      Female              1    46.0          Yes
# 3     CUST-0089      Female              1    63.0          Yes
# 4     CUST-0919      Female              0     8.0          Yes
# ...         ...         ...            ...     ...          ...
# 1025  CUST-0088      Female              0    26.0          Yes
# 1026  CUST-0331        Male              0    49.0          Yes
# 1027  CUST-0467        Male              1    69.0          Yes
# 1028  CUST-0122      Female              1     3.0          Yes
# 1029  CUST-0861    Female                0    49.0          Yes
#
#      InternetService        Contract PaperlessBilling     PaymentMethod  \
# 0        Fiber optic  Month-to-month               No     Credit card
# ...

# %%
df.drop(['customerID'],axis = 1,inplace = True)

# %%
df.drop_duplicates(inplace = True)

# %%
df[['gender','PaymentMethod']] = df[['gender','PaymentMethod']].apply(lambda x : x.str.strip())

# %%
df[['Churn','PhoneService','PaperlessBilling']] = df[['Churn','PhoneService','PaperlessBilling']].apply(lambda x : x.str.strip().str.title())

# %%
contract_map = {
    'Month-to-month':'Month-to-month',
    'Two year':'Two year',
    'month to month': 'Month-to-month',
    'One year': 'One year',
    'month-to-month': 'Month-to-month',
    'Monthly': 'Month-to-month',
    'Two Year': 'Two year',
    '1 year': 'One year',
    '2 year': 'Two year',
    'two year': 'Two year',
    'One Year': 'One year',
    'one year': 'One year'
}

# %%
df['Contract'] = df['Contract'].map(contract_map).values
df['Contract']
# Out:
# 0       Month-to-month
# 1             Two year
# 2       Month-to-month
# 3       Month-to-month
# 4       Month-to-month
#              ...
# 1025          One year
# 1026          Two year
# 1027          Two year
# 1028          Two year
# 1029    Month-to-month
# Name: Contract, Length: 1000, dtype: object

# %%
InternetService_map = {
   'Fiber optic': 'Fiber optic',
    'DSl': 'DSL',
   'DSL': 'DSL',
    'dsl': 'DSL',
    'No': 'No',
   'fiber optic': 'Fiber optic',
   'FiberOptic': 'Fiber optic',
    'Fibre optic':'Fiber optic',
   'Dsl': 'DSL',
    'NO': 'No',
   'nan': 'No',
    'no': 'No'
}

# %%
df['InternetService'] = df['InternetService'].map(InternetService_map).fillna('No')
df['InternetService']
# Out:
# 0       Fiber optic
# 1       Fiber optic
# 2       Fiber optic
# 3       Fiber optic
# 4               DSL
#            ...
# 1025            DSL
# 1026    Fiber optic
# 1027            DSL
# 1028             No
# 1029            DSL
# Name: InternetService, Length: 1000, dtype: object

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors = 'coerce')

# %%
df = df[df['tenure'] > 0]
df
# Out:
#       gender  SeniorCitizen  tenure PhoneService InternetService  \
# 0       Male              0    21.0          Yes     Fiber optic
# 1       Male              0    55.0          Yes     Fiber optic
# 2     Female              1    46.0          Yes     Fiber optic
# 3     Female              1    63.0          Yes     Fiber optic
# 4     Female              0     8.0          Yes             DSL
# ...      ...            ...     ...          ...             ...
# 1025  Female              0    26.0          Yes             DSL
# 1026    Male              0    49.0          Yes     Fiber optic
# 1027    Male              1    69.0          Yes             DSL
# 1028  Female              1     3.0          Yes              No
# 1029  Female              0    49.0          Yes             DSL
#
#             Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# 0     Month-to-month               No       Credit card           29.73
# ...

# %%
df = df[(df['MonthlyCharges'] > 10) & (df['MonthlyCharges'] < 200)]
df
# Out:
#       gender  SeniorCitizen  tenure PhoneService InternetService  \
# 0       Male              0    21.0          Yes     Fiber optic
# 1       Male              0    55.0          Yes     Fiber optic
# 2     Female              1    46.0          Yes     Fiber optic
# 3     Female              1    63.0          Yes     Fiber optic
# 4     Female              0     8.0          Yes             DSL
# ...      ...            ...     ...          ...             ...
# 1025  Female              0    26.0          Yes             DSL
# 1026    Male              0    49.0          Yes     Fiber optic
# 1027    Male              1    69.0          Yes             DSL
# 1028  Female              1     3.0          Yes              No
# 1029  Female              0    49.0          Yes             DSL
#
#             Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# 0     Month-to-month               No       Credit card           29.73
# ...

# %%
df['MonthlyCharges'] = df['MonthlyCharges'].fillna(df['MonthlyCharges'].mean())
# Out:
# /tmp/ipykernel_15982/1821109709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MonthlyCharges'] = df['MonthlyCharges'].fillna(df['MonthlyCharges'].mean())

# %%
df['TotalCharges'] =  df['TotalCharges'].fillna(df['TotalCharges'].mean())
# Out:
# /tmp/ipykernel_15982/1953819416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalCharges'] =  df['TotalCharges'].fillna(df['TotalCharges'].mean())

# %%
df['tenure'] = df['tenure'].fillna(round(df['tenure'].median(),2))
# Out:
# /tmp/ipykernel_15982/2388605195.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tenure'] = df['tenure'].fillna(round(df['tenure'].median(),2))

# %%
print(f" shape of the cleaned DataFrame {df.shape}")
# Out:
#  shape of the cleaned DataFrame (867, 11)

# %%
print(f"missing value counts {df.isna().sum().sum()}")
# Out:
# missing value counts 0

# %%
X = df.drop(['Churn'],axis=1)
y = df['Churn']

# %%
contract_map = {
    'Month-to-month':'Month-to-month',
    'Two year':'Two year',
    'month to month': 'Month-to-month',
    'One year': ' One year',
    'month-to-month': 'Month-to-month',
    'Monthly': 'Month-to-month',
    'Two Year': 'Two year',
    '1 year': ' One year',
    '2 year': 'Two year',
    'two year': ' Two year',
    'One Year': 'One year',
    'one year': 'One year'
}

df['Contract'] = df['Contract'].map(contract_map).values
df['Contract']

df['InternetService'].unique()

InternetService_map = {
   'Fiber optic': 'Fiber optic',
    'DSl': 'DSL',
   'DSL': 'DSL',
    'dsl': 'DSL',
    'No': 'No',
   'fiber optic': 'Fiber optic',
   'FiberOptic': ' Fiber optic',
    'Fibre optic':' Fiber optic',
   'Dsl': 'DSL',
    'NO': 'No',
   'nan': 'No',
    'no': 'No'
}

df['InternetService'] = df['InternetService'].map(InternetService_map).fillna('No')


df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors = 'coerce')
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

df = pd.get_dummies(df,['gender', 'PhoneService', 'InternetService', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first = True)

X = df.drop(['Churn'],axis=1)
y = df['Churn']
# Out:
# /tmp/ipykernel_15982/2017620172.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract'] = df['Contract'].map(contract_map).values
# /tmp/ipykernel_15982/2017620172.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InternetService'] = df['InternetService'].map(InternetService_map).fillna('No')
# /tmp/ipykernel_15982/2017620172.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
model = LogisticRegression()
model.fit(X,y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
tenure = int(input("Enter tenure (months):"))
# Out:
# Enter tenure (months):1

# %%
MonthlyCharges = float(input("Enter Monthly Charges:"))
# Out:
# Enter Monthly Charges:1

# %%
TotalCharges = float(input("Enter Total Charges:"))
# Out:
# Enter Total Charges:1

# %%
SeniorCitizen =int(input("Senior Citizen? (1 = Yes, 0 = No):"))
# Out:
# Senior Citizen? (1 = Yes, 0 = No):1

# %%
Contract = int(input("Contract type (0 = Month-to-month, 1 = One year, 2 = Two year):"))
# Out:
# Contract type (0 = Month-to-month, 1 = One year, 2 = Two year):1

# %%
Contract_Month_to_month=False
Contract_One_year=False
Contract_Two_year=False
if Contract == 0:
  Contract_Month_to_month = True
elif Contract == 1:
  Contract_One_year = True
elif Contract == 2:
  Contract_Two_year = True

# %%
data = {
     "SeniorCitizen":SeniorCitizen,
    "tenure": tenure,
    "MonthlyCharges":MonthlyCharges,
    "TotalCharges":TotalCharges,
    "gender_Male":False,
     "PhoneService_Yes":False,
         "InternetService_Fiber optic": False,
         "InternetService_No":False,
    "Contract_Month-to-month": Contract_Month_to_month,
    "Contract_Two year":Contract_Two_year,
    "PaperlessBilling_Yes":False,
    "PaymentMethod_Credit card":False,
    "PaymentMethod_Electronic check":False,
    "PaymentMethod_Mailed check":False

}

data
# Out:
# {'SeniorCitizen': 1,
#  'tenure': 1,
#  'MonthlyCharges': 1.0,
#  'TotalCharges': 1.0,
#  'gender_Male': False,
#  'PhoneService_Yes': False,
#  'InternetService_Fiber optic': False,
#  'InternetService_No': False,
#  'Contract_Month-to-month': False,
#  'Contract_Two year': False,
#  'PaperlessBilling_Yes': False,
#  'PaymentMethod_Credit card': False,
#  'PaymentMethod_Electronic check': False,
#  'PaymentMethod_Mailed check': False}

# %%
df_new = pd.DataFrame(data,  index=[0])

# %%
df_new
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              1       1             1.0           1.0        False
#
#    PhoneService_Yes  InternetService_Fiber optic  InternetService_No  \
# 0             False                        False               False
#
#    Contract_Month-to-month  Contract_Two year  PaperlessBilling_Yes  \
# 0                    False              False                 False
#
#    PaymentMethod_Credit card  PaymentMethod_Electronic check  \
# 0                      False                           False
#
#    PaymentMethod_Mailed check
# 0                       False

# %%
y_pred = model.predict(df_new)

# %%
print(f"This is the final answer : {y_pred}")
# Out:
# This is the final answer : [0]
