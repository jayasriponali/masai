# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasriponali/masai/blob/main/Leakage_imbalance_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pandas
# !pip3 install scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/cardekho_dataset.csv")
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#         vehicle_age     km_driven       mileage        engine     max_power  \
# count  15411.000000  1.541100e+04  15411.000000  15411.000000  15411.000000
# mean       6.036338  5.561648e+04     19.701151   1486.057751    100.588254
# std        3.013291  5.161855e+04      4.171265    521.106696     42.972979
# min        0.000000  1.000000e+02      4.000000    793.000000     38.400000
# 25%        4.000000  3.000000e+04     17.000000   1197.000000     74.000000
# 50%        6.000000  5.000000e+04     19.670000   1248.000000     88.500000
# 75%        8.000000  7.000000e+04     22.700000   1582.000000    117.300000
# max       29.000000  3.800000e+06     33.540000   6592.000000    626.000000
#
#               seats  selling_price
# count  15411.000000   1.541100e+04
# mean       5.325482   7.749711e+05
# std        0.807628   8.941284e+05
# min        0.000000   4.000000e+04
# 25%        5.000000   3.850000e+05
# 50%        5.000000   5.560000e+05
# ...

# %%
df.shape
# Out:
# (15411, 13)

# %% [markdown]
# # Wrong dtypes
#
#   ### Unnamed column should not exist in the df.
#   ### In df engine column,the actual data  type is float,but it was declared as int.
#
# # Null Values
#
# ### None of the columns have null values.
#
# # Impossible Values
#
# ### Minimum number of seats in the car is showing zero,which is not possible.
#
# ### Max km_driven given as 3800000000,which is impossible.

# %%
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %% [markdown]
# # Drop null target rows
#
# # Impute missing input features
#
# ------
#
# # ANS
#
# # As per the Given Data set there is no null values. Hence nothing can be dropped.
#
# # At the same time, we can not impute the values as there is no null values in the data.

# %% [markdown]
# # Remove duplicates

# %%
df.drop_duplicates()
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
df['mileage']
# Out:
# 0        19.70
# 1        18.90
# 2        17.00
# 3        20.92
# 4        22.77
#          ...
# 15406    19.81
# 15407    17.50
# 15408    21.14
# 15409    16.00
# 15410    18.00
# Name: mileage, Length: 15411, dtype: float64

# %%
df['mileage'] = df['mileage'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df['brand']
# Out:
# 0          Maruti
# 1         Hyundai
# 2         Hyundai
# 3          Maruti
# 4            Ford
#            ...
# 15406     Hyundai
# 15407      Maruti
# 15408       Skoda
# 15409    Mahindra
# 15410       Honda
# Name: brand, Length: 15411, dtype: object

# %%
df['brand'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Ford', 'Renault', 'Mini', 'Mercedes-Benz',
#        'Toyota', 'Volkswagen', 'Honda', 'Mahindra', 'Datsun', 'Tata',
#        'Kia', 'BMW', 'Audi', 'Land Rover', 'Jaguar', 'MG', 'Isuzu',
#        'Porsche', 'Skoda', 'Volvo', 'Lexus', 'Jeep', 'Maserati',
#        'Bentley', 'Nissan', 'ISUZU', 'Ferrari', 'Mercedes-AMG',
#        'Rolls-Royce', 'Force'], dtype=object)

# %% [markdown]
# # Stripping(removing) trailing and leading white spaces from the string.

# %%
df['brand'] = df['brand'].str.strip()

# %% [markdown]
# # Convert brands to lower case.

# %%
df['brand'] = df['brand'].str.lower()

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                vehicle_age  km_driven   mileage    engine  max_power  \
# vehicle_age       1.000000   0.333891 -0.257394  0.098965   0.005208
# km_driven         0.333891   1.000000 -0.105239  0.192885   0.044421
# mileage          -0.257394  -0.105239  1.000000 -0.632987  -0.533128
# engine            0.098965   0.192885 -0.632987  1.000000   0.807368
# max_power         0.005208   0.044421 -0.533128  0.807368   1.000000
# seats             0.030791   0.192830 -0.440280  0.551236   0.172257
# selling_price    -0.241851  -0.080030 -0.305549  0.585844   0.750236
#
#                   seats  selling_price
# vehicle_age    0.030791      -0.241851
# km_driven      0.192830      -0.080030
# mileage       -0.440280      -0.305549
# engine         0.551236       0.585844
# max_power      0.172257       0.750236
# seats          1.000000       0.115033
# selling_price  0.115033       1.000000

# %%
x = df [['car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
       'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
       'max_power', 'seats']]

y = df['selling_price']

x_temp, x_test, y_temp, y_test = train_test_split(x,y, test_size=.15, random_state=42)

x_train, x_val, y_train, y_val = train_test_split(x_temp, y_temp, test_size=0.18, random_state=42)

# %%
y_train
# Out:
# 9671      745000
# 11639     465000
# 3947      262000
# 12067    1499000
# 15070     465000
#           ...
# 6937      500000
# 3880     1549000
# 2042      310000
# 11135     245000
# 5244      211000
# Name: selling_price, Length: 10741, dtype: int64

# %% [markdown]
# #Base line for a regression problem: always predict the mean.

# %%
base_line_prediction = np.mean(y_train)
base_line_predictions = np.full(len(y_val), base_line_prediction)
# Out:
# array([777268.1314589, 777268.1314589, 777268.1314589, ...,
#        777268.1314589, 777268.1314589, 777268.1314589])

# %% [markdown]
# # Compare baseline error to your model's error.

# %%
from sklearn.metrics import mean_absolute_error

baseline_mae = mean_absolute_error(y_val, base_line_predictions)
print(f"Baseline MAE : {baseline_mae}")
# Out:
# Baseline MAE : 436985.7169017531
