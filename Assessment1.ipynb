# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasriponali/masai/blob/main/Assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pandas
# !pip3 install numpy

# %%
import pandas as pd

import numpy as np

# %%
data = {
    'order_id':        [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'customer_city':   ['Mumbai', 'Delhi', 'Mumbai', 'Pune', 'Delhi', 'Mumbai', 'Pune', 'Delhi', 'Mumbai', 'Pune'],
    'cuisine_type':    ['Italian', 'Chinese', 'Italian', 'Indian', 'Chinese', 'Indian', 'Italian', 'Indian', 'Chinese', 'Italian'],
    'delivery_time':   [30, 45, None, 50, 40, 35, None, 55, 42, 38],
    'order_amount':    [250, 400, 300, 150, 500, 200, 350, 450, None, 275],
    'is_delivered':    [True, True, False, True, True, True, False, True, True, True]
}

# %% [markdown]
# ##Task 1

# %%
df = pd.DataFrame(data)
df
# Out:
#    order_id customer_city cuisine_type  delivery_time  order_amount  \
# 0       101        Mumbai      Italian           30.0         250.0
# 1       102         Delhi      Chinese           45.0         400.0
# 2       103        Mumbai      Italian            NaN         300.0
# 3       104          Pune       Indian           50.0         150.0
# 4       105         Delhi      Chinese           40.0         500.0
# 5       106        Mumbai       Indian           35.0         200.0
# 6       107          Pune      Italian            NaN         350.0
# 7       108         Delhi       Indian           55.0         450.0
# 8       109        Mumbai      Chinese           42.0           NaN
# 9       110          Pune      Italian           38.0         275.0
#
#    is_delivered
# 0          True
# 1          True
# 2         False
# 3          True
# 4          True
# 5          True
# 6         False
# 7          True
# 8          True
# 9          True

# %%
df.shape
# Out:
# (10, 6)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull().sum()
# Out:
# order_id         0
# customer_city    0
# cuisine_type     0
# delivery_time    2
# order_amount     1
# is_delivered     0
# dtype: int64

# %% [markdown]
# ##Task2

# %%
df.describe()
# Out:
#         order_id  delivery_time  order_amount
# count   10.00000        8.00000      9.000000
# mean   105.50000       41.87500    319.444444
# std      3.02765        8.06115    115.770367
# min    101.00000       30.00000    150.000000
# 25%    103.25000       37.25000    250.000000
# 50%    105.50000       41.00000    300.000000
# 75%    107.75000       46.25000    400.000000
# max    110.00000       55.00000    500.000000

# %%
df['delivery_time'].median()
# Out:
# 41.0

# %%
df['order_amount'].mean()
# Out:
# np.float64(319.44444444444446)

# %% [markdown]
# ##Task4

# %%
array = df.loc[:,'order_amount']
print(array)
# Out:
# 0    250.0
# 1    400.0
# 2    300.0
# 3    150.0
# 4    500.0
# 5    200.0
# 6    350.0
# 7    450.0
# 8      NaN
# 9    275.0
# Name: order_amount, dtype: float64

# %%
mean_array = np.mean(array)
print(mean_array)
# Out:
# 319.44444444444446

# %%
std_array = np.std(array)
print(std_array)
# Out:
# 109.14934835771389

# %%
max_a = np.max(array)
print(max_a)
# Out:
# 500.0

# %%
min_a = np.min(array)
print(min_a)
# Out:
# 150.0
